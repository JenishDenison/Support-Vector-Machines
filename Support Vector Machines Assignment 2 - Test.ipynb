# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("SalaryData_Test.csv")

# %%
df.head()
# Out:
#    age   workclass      education  educationno        maritalstatus  \
# 0   25     Private           11th            7        Never-married
# 1   38     Private        HS-grad            9   Married-civ-spouse
# 2   28   Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3   44     Private   Some-college           10   Married-civ-spouse
# 4   34     Private           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15060 entries, 0 to 15059
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            15060 non-null  int64
#  1   workclass      15060 non-null  object
#  2   education      15060 non-null  object
#  3   educationno    15060 non-null  int64
#  4   maritalstatus  15060 non-null  object
#  5   occupation     15060 non-null  object
#  6   relationship   15060 non-null  object
#  7   race           15060 non-null  object
#  8   sex            15060 non-null  object
#  9   capitalgain    15060 non-null  int64
#  10  capitalloss    15060 non-null  int64
#  11  hoursperweek   15060 non-null  int64
#  12  native         15060 non-null  object
#  13  Salary         15060 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %% [markdown]
# ### converting all columns to numeric format

# %%
df['workclass'].unique()
# Out:
# array([' Private', ' Local-gov', ' Self-emp-not-inc', ' Federal-gov',
#        ' State-gov', ' Self-emp-inc', ' Without-pay'], dtype=object)

# %%
df['workclass'] = df['workclass'].map({' Private':0,
                                       ' Local-gov':1,
                                       ' Self-emp-not-inc':2,
                                       ' Federal-gov':3,
                                       ' State-gov':4,
                                       ' Self-emp-inc':5, 
                                       ' Without-pay':6}).astype(int)

# %%
df.head()
# Out:
#    age  workclass      education  educationno        maritalstatus  \
# 0   25          0           11th            7        Never-married
# 1   38          0        HS-grad            9   Married-civ-spouse
# 2   28          1     Assoc-acdm           12   Married-civ-spouse
# 3   44          0   Some-college           10   Married-civ-spouse
# 4   34          0           10th            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
df['workclass'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6])

# %%
df['education'].unique()
# Out:
# array([' 11th', ' HS-grad', ' Assoc-acdm', ' Some-college', ' 10th',
#        ' Prof-school', ' 7th-8th', ' Bachelors', ' Masters', ' 5th-6th',
#        ' Assoc-voc', ' 9th', ' Doctorate', ' 12th', ' 1st-4th',
#        ' Preschool'], dtype=object)

# %%
df['education'] = df['education'].map({' 11th':0,
                                       ' HS-grad':1,
                                       ' Assoc-acdm':2,
                                       ' Some-college':3,
                                       ' 10th':4,
                                       ' Prof-school':5,
                                       ' 7th-8th':6,
                                       ' Bachelors':7,
                                       ' Masters':8,
                                       ' 5th-6th':9,
                                       ' Assoc-voc':10,
                                       ' 9th':11,
                                       ' Doctorate':12,
                                       ' 12th':13,
                                       ' 1st-4th':14,
                                       ' Preschool':16}).astype(int)

# %%
df.head()
# Out:
#    age  workclass  education  educationno        maritalstatus  \
# 0   25          0          0            7        Never-married
# 1   38          0          1            9   Married-civ-spouse
# 2   28          1          2           12   Married-civ-spouse
# 3   44          0          3           10   Married-civ-spouse
# 4   34          0          4            6        Never-married
#
#            occupation    relationship    race    sex  capitalgain  \
# 0   Machine-op-inspct       Own-child   Black   Male            0
# 1     Farming-fishing         Husband   White   Male            0
# 2     Protective-serv         Husband   White   Male            0
# 3   Machine-op-inspct         Husband   Black   Male         7688
# 4       Other-service   Not-in-family   White   Male            0
#
#    capitalloss  hoursperweek          native  Salary
# 0            0            40   United-States   <=50K
# 1            0            50   United-States   <=50K
# 2            0            40   United-States    >50K
# 3            0            40   United-States    >50K
# 4            0            30   United-States   <=50K

# %%
df['maritalstatus'].unique()
# Out:
# array([' Never-married', ' Married-civ-spouse', ' Widowed', ' Separated',
#        ' Divorced', ' Married-spouse-absent', ' Married-AF-spouse'],
#       dtype=object)

# %%
df['maritalstatus']=df['maritalstatus'].map({' Never-married':0,
                                             ' Married-civ-spouse':1,
                                             ' Widowed':2,
                                             ' Separated':3,
                                             ' Divorced':4,
                                             ' Married-spouse-absent':5,
                                             ' Married-AF-spouse':6,}).astype(int)

# %%
df.head()
# Out:
#    age  workclass  education  educationno  maritalstatus          occupation  \
# 0   25          0          0            7              0   Machine-op-inspct
# 1   38          0          1            9              1     Farming-fishing
# 2   28          1          2           12              1     Protective-serv
# 3   44          0          3           10              1   Machine-op-inspct
# 4   34          0          4            6              0       Other-service
#
#      relationship    race    sex  capitalgain  capitalloss  hoursperweek  \
# 0       Own-child   Black   Male            0            0            40
# 1         Husband   White   Male            0            0            50
# 2         Husband   White   Male            0            0            40
# 3         Husband   Black   Male         7688            0            40
# 4   Not-in-family   White   Male            0            0            30
#
#            native  Salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States    >50K
# 3   United-States    >50K
# 4   United-States   <=50K

# %%
df['occupation'].unique()
# Out:
# array([' Machine-op-inspct', ' Farming-fishing', ' Protective-serv',
#        ' Other-service', ' Prof-specialty', ' Craft-repair',
#        ' Adm-clerical', ' Exec-managerial', ' Tech-support', ' Sales',
#        ' Priv-house-serv', ' Transport-moving', ' Handlers-cleaners',
#        ' Armed-Forces'], dtype=object)

# %%
df['occupation'] = df['occupation'].map({' Machine-op-inspct':0,
                                         ' Farming-fishing':1,
                                         ' Protective-serv':2,
                                         ' Other-service':3,
                                         ' Prof-specialty':4,
                                         ' Craft-repair':5,
                                         ' Adm-clerical':6,
                                         ' Exec-managerial':7,
                                         ' Tech-support':8,
                                         ' Sales':9,
                                         ' Priv-house-serv':10,
                                         ' Transport-moving':11,
                                         ' Handlers-cleaners':12,
                                         ' Armed-Forces':13}).astype(int)

# %%
df.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          0          0            7              0           0
# 1   38          0          1            9              1           1
# 2   28          1          2           12              1           2
# 3   44          0          3           10              1           0
# 4   34          0          4            6              0           3
#
#      relationship    race    sex  capitalgain  capitalloss  hoursperweek  \
# 0       Own-child   Black   Male            0            0            40
# 1         Husband   White   Male            0            0            50
# 2         Husband   White   Male            0            0            40
# 3         Husband   Black   Male         7688            0            40
# 4   Not-in-family   White   Male            0            0            30
#
#            native  Salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States    >50K
# 3   United-States    >50K
# 4   United-States   <=50K

# %%
df['relationship'].unique()
# Out:
# array([' Own-child', ' Husband', ' Not-in-family', ' Unmarried', ' Wife',
#        ' Other-relative'], dtype=object)

# %%
df['relationship']=df['relationship'].map({' Own-child':0,
                                           ' Husband':1,
                                           ' Not-in-family':2,
                                           ' Unmarried':3,
                                           ' Wife':4,
                                           ' Other-relative':5}).astype(int)

# %%
df.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          0          0            7              0           0
# 1   38          0          1            9              1           1
# 2   28          1          2           12              1           2
# 3   44          0          3           10              1           0
# 4   34          0          4            6              0           3
#
#    relationship    race    sex  capitalgain  capitalloss  hoursperweek  \
# 0             0   Black   Male            0            0            40
# 1             1   White   Male            0            0            50
# 2             1   White   Male            0            0            40
# 3             1   Black   Male         7688            0            40
# 4             2   White   Male            0            0            30
#
#            native  Salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States    >50K
# 3   United-States    >50K
# 4   United-States   <=50K

# %%
df['race'].unique()
# Out:
# array([' Black', ' White', ' Other', ' Amer-Indian-Eskimo',
#        ' Asian-Pac-Islander'], dtype=object)

# %%
df['race']=df['race'].map({' Black':0,
                           ' White':1,
                           ' Other':2,
                           ' Amer-Indian-Eskimo':3,
                           ' Asian-Pac-Islander':4}).astype(int)

# %%
df.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          0          0            7              0           0
# 1   38          0          1            9              1           1
# 2   28          1          2           12              1           2
# 3   44          0          3           10              1           0
# 4   34          0          4            6              0           3
#
#    relationship  race    sex  capitalgain  capitalloss  hoursperweek  \
# 0             0     0   Male            0            0            40
# 1             1     1   Male            0            0            50
# 2             1     1   Male            0            0            40
# 3             1     0   Male         7688            0            40
# 4             2     1   Male            0            0            30
#
#            native  Salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States    >50K
# 3   United-States    >50K
# 4   United-States   <=50K

# %%
df['sex'].unique()
# Out:
# array([' Male', ' Female'], dtype=object)

# %%
df['sex'] = df['sex'].map({' Male': 0,
                           ' Female': 1}).astype(int)

# %%
df.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          0          0            7              0           0
# 1   38          0          1            9              1           1
# 2   28          1          2           12              1           2
# 3   44          0          3           10              1           0
# 4   34          0          4            6              0           3
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0             0     0    0            0            0            40
# 1             1     1    0            0            0            50
# 2             1     1    0            0            0            40
# 3             1     0    0         7688            0            40
# 4             2     1    0            0            0            30
#
#            native  Salary
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States    >50K
# 3   United-States    >50K
# 4   United-States   <=50K

# %%
df['native'].unique()
# Out:
# array([' United-States', ' Peru', ' Guatemala', ' Mexico',
#        ' Dominican-Republic', ' Ireland', ' Germany', ' Philippines',
#        ' Thailand', ' Haiti', ' El-Salvador', ' Puerto-Rico', ' Vietnam',
#        ' South', ' Columbia', ' Japan', ' India', ' Cambodia', ' Poland',
#        ' Laos', ' England', ' Cuba', ' Taiwan', ' Italy', ' Canada',
#        ' Portugal', ' China', ' Nicaragua', ' Honduras', ' Iran',
#        ' Scotland', ' Jamaica', ' Ecuador', ' Yugoslavia', ' Hungary',
#        ' Hong', ' Greece', ' Trinadad&Tobago',
#        ' Outlying-US(Guam-USVI-etc)', ' France'], dtype=object)

# %%
df['native']=df['native'].map({' United-States':0,
                               ' Peru':1,
                               ' Guatemala':2,
                               ' Mexico':3,
                               ' Dominican-Republic':4,
                               ' Ireland':5,
                               ' Germany':6,
                               ' Philippines':7,
                               ' Thailand':8,
                               ' Haiti':9,
                               ' El-Salvador':10,
                               ' Puerto-Rico':11,
                               ' Vietnam':12,
                               ' South':13,
                               ' Columbia':14,
                               ' Japan':15,
                               ' India':16,
                               ' Cambodia':17,
                               ' Poland':18,
                               ' Laos':19,
                               ' England':20,
                               ' Cuba':21,
                               ' Taiwan':22,
                               ' Italy':23,
                               ' Canada':24,
                               ' Portugal':25,
                               ' China':26,
                               ' Nicaragua':27,
                               ' Honduras':28,
                               ' Iran':29,
                               ' Scotland':30,
                               ' Jamaica':31,
                               ' Ecuador':32,
                               ' Yugoslavia':33,
                               ' Hungary':34,
                               ' Hong':35,
                               ' Greece':36,
                               ' Trinadad&Tobago':37,
                               ' Outlying-US(Guam-USVI-etc)':38,
                               ' France':39}).astype(int)

# %%
df.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          0          0            7              0           0
# 1   38          0          1            9              1           1
# 2   28          1          2           12              1           2
# 3   44          0          3           10              1           0
# 4   34          0          4            6              0           3
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             0     0    0            0            0            40       0
# 1             1     1    0            0            0            50       0
# 2             1     1    0            0            0            40       0
# 3             1     0    0         7688            0            40       0
# 4             2     1    0            0            0            30       0
#
#    Salary
# 0   <=50K
# 1   <=50K
# 2    >50K
# 3    >50K
# 4   <=50K

# %%
df['Salary'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %%
df['Salary']=df['Salary'].map({' <=50K':0,
                               ' >50K':1}).astype(int)

# %%
df.head()
# Out:
#    age  workclass  education  educationno  maritalstatus  occupation  \
# 0   25          0          0            7              0           0
# 1   38          0          1            9              1           1
# 2   28          1          2           12              1           2
# 3   44          0          3           10              1           0
# 4   34          0          4            6              0           3
#
#    relationship  race  sex  capitalgain  capitalloss  hoursperweek  native  \
# 0             0     0    0            0            0            40       0
# 1             1     1    0            0            0            50       0
# 2             1     1    0            0            0            40       0
# 3             1     0    0         7688            0            40       0
# 4             2     1    0            0            0            30       0
#
#    Salary
# 0       0
# 1       0
# 2       1
# 3       1
# 4       0

# %%
from sklearn.preprocessing import StandardScaler

from sklearn import svm
from sklearn.svm import SVC
from sklearn.metrics import classification_report


from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split, cross_val_score

# %%
array = df.values
X = array[:,0:13]
Y = array[:,13]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.3)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((10542, 13), (10542,), (4518, 13), (4518,))

# %%
from sklearn.svm import SVC

classifier = SVC()

classifier.fit(X_train, y_train)

score = classifier.score(X_test, y_test)

print(score)
# Out:
# 0.8078795927401505

# %%
import seaborn as sns
import matplotlib.pyplot as pplt

corrmat = df.corr()
f, ax = pplt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
k = 8 
cols = corrmat.nlargest(k, 'Salary')['Salary'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
pplt.show()

# %%
X = df[['educationno', 'age', 'hoursperweek', 'capitalgain', 'education', 'capitalloss']]
Y = df['Salary']

X_train, x_test, Y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
classifier = SVC()

classifier.fit(X_train, Y_train)

score = classifier.score(x_test, y_test)

print(score)
# Out:
# 0.796812749003984

# %% [markdown]
# the score is better when we take all the column
